# %% [markdown]
# ### stat_market home assignment

# %% [markdown]
# ### improt libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from bubble_plot.bubble_plot import bubble_plot
import numpy as np
import seaborn as sns
import xgboost as xgb
import re
import shap
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### read data

# %%
df = pd.read_csv("diabetic_data.csv")

# %%
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 0                 1  ...          No      No                   No
# 1                 3  ...          No      Up                   No
# 2                 2  ...          No      No                   No
# 3                 2  ...          No      Up                   No
# 4                 1  ...          No  Steady                   No
#
#    glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                   No                        No                       No
# 1                   No                        No                       No
# 2                   No                        No                       No
# 3                   No                        No                       No
# 4                   No                        No                       No
#
#    metformin-pioglitazone  change diabetesMed readmitted
# 0                      No      No          No         NO
# 1                      No      Ch         Yes        >30
# 2                      No      No         Yes         NO
# 3                      No      Ch         Yes         NO
# 4                      No      Ch         Yes         NO
#
# [5 rows x 50 columns]

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ### missing returns 0, but we can see that this data has unique signs for missing such as "?"

# %% [markdown]
# ### hist for int type columns

# %%
for col in df.select_dtypes(include=['int64']).columns.tolist():
    plt.hist(df[col],bins=30)
    plt.title(col)
    plt.show()

# %% [markdown]
# ### hist insights:
#     1. some columns are not continous. will move them to the categorical list.

# %%
#list of discrete looking from hist
discrete = ['admission_type_id',"discharge_disposition_id","admission_source_id"]

#list of num's
nums = ["num_procedures","number_diagnoses"]
cat = df.select_dtypes(include=['object']).columns.tolist()
cat = cat + discrete
#remove id's
cat = [c for c in cat if c not in ["encounter_id","patient_nbr","readmitted"]+nums]

num = df.select_dtypes(include=['int64']).columns.tolist()
num = [c for c in num if c not in discrete+["encounter_id","patient_nbr","readmitted"]]

num = num + nums
num = list(set(num))

# %%
# convert age to numeric by this map:
map_age = {"[70-80)":70,
      "[60-70)":60,
      "[50-60)":50,
      "[80-90)":80,
      "[40-50)":40,
      "[30-40)":30,
      "[90-100)":90,
      "[20-30)":20,
      "[10-20)":10,
      "[0-10)":0}
df["age_num"] = df["age"].map(map_age)
df[["age","age_num"]].head()
# Out:
#        age  age_num
# 0   [0-10)        0
# 1  [10-20)       10
# 2  [20-30)       20
# 3  [30-40)       30
# 4  [40-50)       40

# %%
num = num+['age_num']
cat.remove('age')

# %% [markdown]
# ### plot correlation heat map

# %%
corr = df[num].corr()

# %%
sns.heatmap(corr)
plt.show()

# %% [markdown]
# ### corr insights:
#     1. time in hospital has high positive correlation with number of medications

# %%
#sns.pairplot(df[num+["readmitted"]], hue="readmitted")
#plt.show()

# %% [markdown]
# ### examine the number of unique values per categorical feature with its distribution.

# %%
for col in cat:
    print("{}'s number of unique values: {} \n".format(col,df[col].nunique()))
    print(" and their distribution : \n")
    print(df[col].value_counts(normalize=True))
    print("\n")
# Out:
# race's number of unique values: 6
#
#  and their distribution :
#
# Caucasian          0.747784
# AfricanAmerican    0.188766
# ?                  0.022336
# Hispanic           0.020017
# Other              0.014799
# Asian              0.006299
# Name: race, dtype: float64
#
#
# gender's number of unique values: 3
#
#  and their distribution :
#
# Female             0.537586
# Male               0.462384
# Unknown/Invalid    0.000029
# Name: gender, dtype: float64
#
#
# weight's number of unique values: 10
#
#  and their distribution :
#
# ?            0.968585
# [75-100)     0.013128
# [50-75)      0.008814
# [100-125)    0.006142
# [125-150)    0.001425
# [25-50)      0.000953
# [0-25)       0.000472
# [150-175)    0.000344
# [175-200)    0.000108
# >200         0.000029
# Name: weight, dtype: float64
#
#
# payer_code's number of unique values: 18
#
#  and their distribution :
#
# ?     0.395574
# MC    0.318761
# HM    0.061651
# SP    0.049201
# BC    0.045742
# MD    0.034707
# CP    0.024890
# UN    0.024055
# CM    0.019034
# OG    0.010151
# PO    0.005817
# DM    0.005395
# CH    0.001435
# WC    0.001327
# OT    0.000934
# MP    0.000776
# SI    0.000540
# FR    0.000010
# Name: payer_code, dtype: float64
#
#
# medical_specialty's number of unique values: 73
#
#  and their distribution :
#
# ?                                    0.490822
# InternalMedicine                     0.143810
# Emergency/Trauma                     0.074337
# Family/GeneralPractice               0.073109
# Cardiology                           0.052591
# Surgery-General                      0.030452
# Nephrology                           0.015850
# Orthopedics                          0.013757
# Orthopedics-Reconstructive           0.012116
# Radiologist                          0.011202
# Pulmonology                          0.008559
# Psychiatry                           0.008392
# Urology                              0.006731
# ObstetricsandGynecology              0.006594
# Surgery-Cardiovascular/Thoracic      0.006407
# Gastroenterology                     0.005542
# Surgery-Vascular                     0.005238
# Surgery-Neuro                        0.004599
# PhysicalMedicineandRehabilitation    0.003842
# Oncology                             0.003420
# Pediatrics                           0.002496
# Hematology/Oncology                  0.002034
# Neurology                            0.001995
# Pediatrics-Endocrinology             0.001562
# Otolaryngology                       0.001228
# Endocrinology                        0.001179
# Surgery-Thoracic                     0.001071
# Psychology                           0.000992
# Podiatry                             0.000983
# Surgery-Cardiovascular               0.000963
#                                        ...
# Obstetrics                           0.000187
# Anesthesiology-Pediatric             0.000187
# Pathology                            0.000167
# Rheumatology                         0.000167
# Anesthesiology                       0.000118
# OutreachServices                     0.000118
# Surgery-Maxillofacial                0.000108
# PhysicianNotFound                    0.000108
# Surgery-Colon&Rectal                 0.000108
# Pediatrics-Neurology                 0.000098
# Surgery-Pediatric                    0.000079
# Endocrinology-Metabolism             0.000079
# AllergyandImmunology                 0.000069
# Cardiology-Pediatric                 0.000069
# Psychiatry-Child/Adolescent          0.000069
# DCPTEAM                              0.000059
# Pediatrics-Hematology-Oncology       0.000039
# Dentistry                            0.000039
# Pediatrics-EmergencyMedicine         0.000029
# Pediatrics-AllergyandImmunology      0.000029
# Resident                             0.000020
# Psychiatry-Addictive                 0.000010
# Dermatology                          0.000010
# Speech                               0.000010
# Perinatology                         0.000010
# SportsMedicine                       0.000010
# Neurophysiology                      0.000010
# Surgery-PlasticwithinHeadandNeck     0.000010
# Pediatrics-InfectiousDiseases        0.000010
# Proctology                           0.000010
# Name: medical_specialty, Length: 73, dtype: float64
#
#
# diag_1's number of unique values: 717
#
#  and their distribution :
#
# 428       0.067429
# 414       0.064668
# 786       0.039463
# 410       0.035513
# 486       0.034471
# 427       0.027180
# 491       0.022355
# 715       0.021137
# 682       0.020066
# 434       0.019928
# 780       0.019840
# 996       0.019329
# 276       0.018562
# 38        0.016587
# 250.8     0.016508
# 599       0.015673
# 584       0.014936
# V57       0.011861
# 250.6     0.011625
# 518       0.010957
# 820       0.010632
# 577       0.010387
# 493       0.010377
# 435       0.009984
# 562       0.009718
# 574       0.009483
# 296       0.008805
# 560       0.008608
# 250.7     0.008559
# 250.13    0.008362
#             ...
# 915       0.000010
# 885       0.000010
# V07       0.000010
# 84        0.000010
# V67       0.000010
# 216       0.000010
# 10        0.000010
# 605       0.000010
# V25       0.000010
# 97        0.000010
# 523       0.000010
# 939       0.000010
# 832       0.000010
# 690       0.000010
# 988       0.000010
# 994       0.000010
# 477       0.000010
# E909      0.000010
# 375       0.000010
# 57        0.000010
# 976       0.000010
# 791       0.000010
# 700       0.000010
# 684       0.000010
# 114       0.000010
# 837       0.000010
# 834       0.000010
# 704       0.000010
# V60       0.000010
# 804       0.000010
# Name: diag_1, Length: 717, dtype: float64
#
#
# diag_2's number of unique values: 749
#
#  and their distribution :
#
# 276       0.066348
# 428       0.065464
# 250       0.059656
# 427       0.049486
# 401       0.036712
# 496       0.032476
# 599       0.032309
# 403       0.027740
# 414       0.026040
# 411       0.025215
# 250.02    0.020380
# 707       0.019643
# 585       0.018385
# 584       0.016204
# 491       0.015182
# 250.01    0.014966
# 285       0.014936
# 780       0.014651
# 425       0.014091
# 682       0.014081
# 486       0.013551
# 518       0.013315
# 424       0.010524
# 413       0.010239
# 250.6     0.008795
# 493       0.008657
# 305       0.006898
# 786       0.006328
# 280       0.005955
# 998       0.005611
#             ...
# E882      0.000010
# 665       0.000010
# 529       0.000010
# 145       0.000010
# 752       0.000010
# 908       0.000010
# 800       0.000010
# 912       0.000010
# 843       0.000010
# 968       0.000010
# 350       0.000010
# 46        0.000010
# 180       0.000010
# 962       0.000010
# E929      0.000010
# E900      0.000010
# 917       0.000010
# V69       0.000010
# V13       0.000010
# E854      0.000010
# E817      0.000010
# 975       0.000010
# 164       0.000010
# 137       0.000010
# 99        0.000010
# 353       0.000010
# 748       0.000010
# E968      0.000010
# 88        0.000010
# 66        0.000010
# Name: diag_2, Length: 749, dtype: float64
#
#
# diag_3's number of unique values: 790
#
#  and their distribution :
#
# 250       0.113545
# 401       0.081452
# 276       0.050852
# 428       0.044976
# 427       0.038864
# 414       0.036004
# 496       0.025598
# 403       0.023161
# 585       0.019574
# 272       0.019348
# 599       0.019073
# ?         0.013983
# V45       0.013649
# 250.02    0.013452
# 707       0.013364
# 780       0.013109
# 285       0.011792
# 425       0.011163
# 250.6     0.010613
# 424       0.010446
# 584       0.009463
# 305       0.009080
# 250.01    0.008991
# 682       0.008716
# 518       0.008392
# 41        0.007144
# 493       0.006820
# 278       0.006682
# 530       0.006142
# 786       0.005739
#             ...
# 111       0.000010
# V07       0.000010
# E828      0.000010
# 893       0.000010
# E825      0.000010
# E882      0.000010
# 622       0.000010
# 484       0.000010
# 538       0.000010
# 485       0.000010
# 880       0.000010
# 838       0.000010
# E987      0.000010
# 217       0.000010
# E854      0.000010
# V22       0.000010
# 875       0.000010
# 148       0.000010
# E900      0.000010
# 750       0.000010
# 834       0.000010
# E966      0.000010
# 837       0.000010
# 671       0.000010
# 387       0.000010
# 164       0.000010
# 308       0.000010
# 980       0.000010
# 853       0.000010
# 66        0.000010
# Name: diag_3, Length: 790, dtype: float64
#
#
# max_glu_serum's number of unique values: 4
#
#  and their distribution :
#
# None    0.947468
# Norm    0.025519
# >200    0.014592
# >300    0.012421
# Name: max_glu_serum, dtype: float64
#
#
# A1Cresult's number of unique values: 4
#
#  and their distribution :
#
# None    0.832773
# >8      0.080734
# Norm    0.049034
# >7      0.037458
# Name: A1Cresult, dtype: float64
#
#
# metformin's number of unique values: 4
#
#  and their distribution :
#
# No        0.803589
# Steady    0.180276
# Up        0.010485
# Down      0.005650
# Name: metformin, dtype: float64
#
#
# repaglinide's number of unique values: 4
#
#  and their distribution :
#
# No        0.984877
# Steady    0.013600
# Up        0.001081
# Down      0.000442
# Name: repaglinide, dtype: float64
#
#
# nateglinide's number of unique values: 4
#
#  and their distribution :
#
# No        0.993092
# Steady    0.006564
# Up        0.000236
# Down      0.000108
# Name: nateglinide, dtype: float64
#
#
# chlorpropamide's number of unique values: 4
#
#  and their distribution :
#
# No        0.999155
# Steady    0.000776
# Up        0.000059
# Down      0.000010
# Name: chlorpropamide, dtype: float64
#
#
# glimepiride's number of unique values: 4
#
#  and their distribution :
#
# No        0.948991
# Steady    0.045890
# Up        0.003213
# Down      0.001906
# Name: glimepiride, dtype: float64
#
#
# acetohexamide's number of unique values: 2
#
#  and their distribution :
#
# No        0.99999
# Steady    0.00001
# Name: acetohexamide, dtype: float64
#
#
# glipizide's number of unique values: 4
#
#  and their distribution :
#
# No        0.875341
# Steady    0.111589
# Up        0.007566
# Down      0.005503
# Name: glipizide, dtype: float64
#
#
# glyburide's number of unique values: 4
#
#  and their distribution :
#
# No        0.895348
# Steady    0.091131
# Up        0.007979
# Down      0.005542
# Name: glyburide, dtype: float64
#
#
# tolbutamide's number of unique values: 2
#
#  and their distribution :
#
# No        0.999774
# Steady    0.000226
# Name: tolbutamide, dtype: float64
#
#
# pioglitazone's number of unique values: 4
#
#  and their distribution :
#
# No        0.927992
# Steady    0.068549
# Up        0.002299
# Down      0.001160
# Name: pioglitazone, dtype: float64
#
#
# rosiglitazone's number of unique values: 4
#
#  and their distribution :
#
# No        0.937455
# Steady    0.059941
# Up        0.001749
# Down      0.000855
# Name: rosiglitazone, dtype: float64
#
#
# acarbose's number of unique values: 4
#
#  and their distribution :
#
# No        0.996973
# Steady    0.002899
# Up        0.000098
# Down      0.000029
# Name: acarbose, dtype: float64
#
#
# miglitol's number of unique values: 4
#
#  and their distribution :
#
# No        0.999627
# Steady    0.000305
# Down      0.000049
# Up        0.000020
# Name: miglitol, dtype: float64
#
#
# troglitazone's number of unique values: 2
#
#  and their distribution :
#
# No        0.999971
# Steady    0.000029
# Name: troglitazone, dtype: float64
#
#
# tolazamide's number of unique values: 3
#
#  and their distribution :
#
# No        0.999617
# Steady    0.000373
# Up        0.000010
# Name: tolazamide, dtype: float64
#
#
# examide's number of unique values: 1
#
#  and their distribution :
#
# No    1.0
# Name: examide, dtype: float64
#
#
# citoglipton's number of unique values: 1
#
#  and their distribution :
#
# No    1.0
# Name: citoglipton, dtype: float64
#
#
# insulin's number of unique values: 4
#
#  and their distribution :
#
# No        0.465607
# Steady    0.303137
# Down      0.120060
# Up        0.111196
# Name: insulin, dtype: float64
#
#
# glyburide-metformin's number of unique values: 4
#
#  and their distribution :
#
# No        0.993063
# Steady    0.006800
# Up        0.000079
# Down      0.000059
# Name: glyburide-metformin, dtype: float64
#
#
# glipizide-metformin's number of unique values: 2
#
#  and their distribution :
#
# No        0.999872
# Steady    0.000128
# Name: glipizide-metformin, dtype: float64
#
#
# glimepiride-pioglitazone's number of unique values: 2
#
#  and their distribution :
#
# No        0.99999
# Steady    0.00001
# Name: glimepiride-pioglitazone, dtype: float64
#
#
# metformin-rosiglitazone's number of unique values: 2
#
#  and their distribution :
#
# No        0.99998
# Steady    0.00002
# Name: metformin-rosiglitazone, dtype: float64
#
#
# metformin-pioglitazone's number of unique values: 2
#
#  and their distribution :
#
# No        0.99999
# Steady    0.00001
# Name: metformin-pioglitazone, dtype: float64
#
#
# change's number of unique values: 2
#
#  and their distribution :
#
# No    0.538048
# Ch    0.461952
# Name: change, dtype: float64
#
#
# diabetesMed's number of unique values: 2
#
#  and their distribution :
#
# Yes    0.770031
# No     0.229969
# Name: diabetesMed, dtype: float64
#
#
# admission_type_id's number of unique values: 8
#
#  and their distribution :
#
# 1    0.530531
# 3    0.185416
# 2    0.181593
# 6    0.051992
# 5    0.047020
# 8    0.003144
# 7    0.000206
# 4    0.000098
# Name: admission_type_id, dtype: float64
#
#
# discharge_disposition_id's number of unique values: 26
#
#  and their distribution :
#
# 1     0.591887
# 3     0.137118
# 6     0.126781
# 18    0.036269
# 2     0.020911
# 22    0.019584
# 11    0.016135
# 5     0.011635
# 25    0.009718
# 4     0.008009
# 7     0.006122
# 23    0.004049
# 13    0.003921
# 14    0.003655
# 28    0.001366
# 8     0.001061
# 15    0.000619
# 24    0.000472
# 9     0.000206
# 17    0.000138
# 16    0.000108
# 19    0.000079
# 10    0.000059
# 27    0.000049
# 12    0.000029
# 20    0.000020
# Name: discharge_disposition_id, dtype: float64
#
#
# admission_source_id's number of unique values: 17
#
#  and their distribution :
#
# 7     0.564963
# 1     0.290519
# 17    0.066633
# 4     0.031317
# 6     0.022247
# 2     0.010848
# 5     0.008402
# 3     0.001838
# 20    0.001582
# 9     0.001228
# 8     0.000157
# 22    0.000118
# 10    0.000079
# 11    0.000020
# 14    0.000020
# 25    0.000020
# 13    0.000010
# Name: admission_source_id, dtype: float64

# %% [markdown]
# ### we will apply a quick strategy for ategorical columns - bidding by 5%. all values that appear less then 5 % will be replaced by the string "other". and we will remove features with many values completely. in the future we should check the different values that enters "other" and perform hashing trick on the features removed.

# %%
#bidding
df[cat] = df[cat].apply(lambda x: x.mask(x.map(x.value_counts(normalize=True))<0.05, 'other'))

# %%
rmv = ['weight','repaglinide','nateglinide', 'diag_1','diag_2','diag_3','chlorpropamid','acetohexamide','tolbutamide','acarbose','miglitol','troglitazone','tolazamide','examide','citoglipton','glyburide-metformin','glipizide-metformin','glimepiride-pioglitazone','metformin-rosiglitazone','metformin-pioglitazon','']
cat = [c for c in cat if c not in rmv]
cat
# Out:
# ['race',
#  'gender',
#  'payer_code',
#  'medical_specialty',
#  'max_glu_serum',
#  'A1Cresult',
#  'metformin',
#  'chlorpropamide',
#  'glimepiride',
#  'glipizide',
#  'glyburide',
#  'pioglitazone',
#  'rosiglitazone',
#  'insulin',
#  'metformin-pioglitazone',
#  'change',
#  'diabetesMed',
#  'admission_type_id',
#  'discharge_disposition_id',
#  'admission_source_id']

# %% [markdown]
# ### examining the change in the features

# %%
for col in cat:
    print("{}'s number of unique values: {} \n".format(col,df[col].nunique()))
    print(" and their distribution : \n")
    print(df[col].value_counts(normalize=True))
    print("\n")
# Out:
# race's number of unique values: 3
#
#  and their distribution :
#
# Caucasian          0.747784
# AfricanAmerican    0.188766
# other              0.063449
# Name: race, dtype: float64
#
#
# gender's number of unique values: 3
#
#  and their distribution :
#
# Female    0.537586
# Male      0.462384
# other     0.000029
# Name: gender, dtype: float64
#
#
# payer_code's number of unique values: 4
#
#  and their distribution :
#
# ?        0.395574
# MC       0.318761
# other    0.224014
# HM       0.061651
# Name: payer_code, dtype: float64
#
#
# medical_specialty's number of unique values: 6
#
#  and their distribution :
#
# ?                         0.490822
# other                     0.165330
# InternalMedicine          0.143810
# Emergency/Trauma          0.074337
# Family/GeneralPractice    0.073109
# Cardiology                0.052591
# Name: medical_specialty, dtype: float64
#
#
# max_glu_serum's number of unique values: 2
#
#  and their distribution :
#
# None     0.947468
# other    0.052532
# Name: max_glu_serum, dtype: float64
#
#
# A1Cresult's number of unique values: 3
#
#  and their distribution :
#
# None     0.832773
# other    0.086493
# >8       0.080734
# Name: A1Cresult, dtype: float64
#
#
# metformin's number of unique values: 3
#
#  and their distribution :
#
# No        0.803589
# Steady    0.180276
# other     0.016135
# Name: metformin, dtype: float64
#
#
# chlorpropamide's number of unique values: 2
#
#  and their distribution :
#
# No       0.999155
# other    0.000845
# Name: chlorpropamide, dtype: float64
#
#
# glimepiride's number of unique values: 2
#
#  and their distribution :
#
# No       0.948991
# other    0.051009
# Name: glimepiride, dtype: float64
#
#
# glipizide's number of unique values: 3
#
#  and their distribution :
#
# No        0.875341
# Steady    0.111589
# other     0.013069
# Name: glipizide, dtype: float64
#
#
# glyburide's number of unique values: 3
#
#  and their distribution :
#
# No        0.895348
# Steady    0.091131
# other     0.013521
# Name: glyburide, dtype: float64
#
#
# pioglitazone's number of unique values: 3
#
#  and their distribution :
#
# No        0.927992
# Steady    0.068549
# other     0.003459
# Name: pioglitazone, dtype: float64
#
#
# rosiglitazone's number of unique values: 3
#
#  and their distribution :
#
# No        0.937455
# Steady    0.059941
# other     0.002604
# Name: rosiglitazone, dtype: float64
#
#
# insulin's number of unique values: 4
#
#  and their distribution :
#
# No        0.465607
# Steady    0.303137
# Down      0.120060
# Up        0.111196
# Name: insulin, dtype: float64
#
#
# metformin-pioglitazone's number of unique values: 2
#
#  and their distribution :
#
# No       0.99999
# other    0.00001
# Name: metformin-pioglitazone, dtype: float64
#
#
# change's number of unique values: 2
#
#  and their distribution :
#
# No    0.538048
# Ch    0.461952
# Name: change, dtype: float64
#
#
# diabetesMed's number of unique values: 2
#
#  and their distribution :
#
# Yes    0.770031
# No     0.229969
# Name: diabetesMed, dtype: float64
#
#
# admission_type_id's number of unique values: 5
#
#  and their distribution :
#
# 1        0.530531
# 3        0.185416
# 2        0.181593
# 6        0.051992
# other    0.050469
# Name: admission_type_id, dtype: float64
#
#
# discharge_disposition_id's number of unique values: 4
#
#  and their distribution :
#
# 1        0.591887
# other    0.144213
# 3        0.137118
# 6        0.126781
# Name: discharge_disposition_id, dtype: float64
#
#
# admission_source_id's number of unique values: 4
#
#  and their distribution :
#
# 7        0.564963
# 1        0.290519
# other    0.077885
# 17       0.066633
# Name: admission_source_id, dtype: float64

# %%
df = df[df["gender"]!="Unknown/Invalid"]

# %% [markdown]
# ### plotting bar plots. the top of the bar shows the chance of being above_30 for each value.
# ### plus the black line is the confidence interval. overlapping lines means that there is no difference between these values "chances" (mean)

# %%
for col in cat :
   
        plt.figure(figsize=(7,7))
        ax = sns.barplot(data=df, x= col, y = np.where(df['readmitted']==">30",1,0))
        ax.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
        ax.set(xlabel="col", ylabel='above_30')
        ax.set(ylabel = 'above_30')
        plt.title(col)
        plt.show()

# %% [markdown]
# ### above_30 bar plot insights:
#     1. as for race, caucassian and afrecan america have higher rates of being <30 then other
#     2. as for gender, males have lower chances of radmitting >30
#     3. etc
#
#     features that do not have any difference in mean :  glyburide, pioglitazone, chlorpropamide

# %% [markdown]
# ### plotting bar plots. the top of the bar shows the chance of being under_30 for each value.
# ### plus the black line is the confidence interval. overlapping lines meaning that there is no difference between these values "chances" (mean)

# %%
for col in cat:
        plt.figure(figsize=(7,7))
        ax = sns.barplot(data=df, x= col, y = np.where(df['readmitted']=="<30",1,0))
        ax.set(ylabel = 'under_30')
        plt.title(col)
        plt.show()

# %% [markdown]
# ### under_30 bar plot insights:
#     1. as for race, caucassian and afrecan america have higher rates of being <30 then other
#     2. as for payer_code, ? (missing), and MC have higher rates then "other" (low frequency values) and HM
#     3. etc
#
#     features that do not have any difference in mean : gender, glimepiride, glyburide, pioglitazone, rosiglitazone,

# %% [markdown]
# ### add dummy columns for categorical features

# %%
dummies = pd.get_dummies(df[cat])
dummy_cols = dummies.columns.tolist()

# %%
df = pd.concat([df,dummies],axis=1)

# %%
x_col = num + dummy_cols

# %% [markdown]
# ### convert label to int for xgboost

# %%
label_map = {"NO":0,">30":1,"<30":2}
df['y'] = df["readmitted"].map(label_map)

# %%
# make sure all is num
for c in x_col+['y']:
    df[c] = df[c].astype(int)

# %% [markdown]
# ### change column nams for xgboost

# %%
#xgb.DMAtrix dosent like < in column names
aregex = re.compile(r"\[|\]|<", re.IGNORECASE)
df.columns = [regex.sub("_", col) if any(x in str(col) for x in set(('[', ']', '<'))) else col for col in df.columns.values]
dummy_cols = [regex.sub("_", col) if any(x in str(col) for x in set(('[', ']', '<'))) else col for col in dummy_cols]
x_col = num + dummy_cols

# %% [markdown]
# ### define the function that trains xgboost stratified cross validated models

# %%
def train_xgb_cv(X,Y):
    
    '''
    a function that train's a stratified cross validated xgboost multi class classifier,
    and prints the resulted train and test error.
    
    param X : pd.DataFrame
    param Y : pd.DataFrame
    
    returns last trained model
    '''
    
    skf = StratifiedKFold(n_splits=3,shuffle=True)
    

    for train_index, test_index in skf.split(X,Y):
        print(train_index)
        
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = Y.iloc[train_index], Y.iloc[test_index]
        
        param = {"objective" :'multi:softmax',
                 "num_class":3,
                 "colsample_bytree":1,
                 "learning_rate":0.3,
                 "max_depth":12,
                 "subsample":1,
                 "seed":42,
                 'eval_metric': 'mlogloss',
                 'base_score': 0.3,
                 #'alpha':10
                     }
        
        num_round=10
        #weight=np.where(y_train["answer"]==1,1,0.7)
        dtrain = xgb.DMatrix(X_train, label=y_train)  #,weight=weight
        dtest = xgb.DMatrix(X_test, label=y_test)

        watchlist=[(dtrain,'train'),(dtest,'test')]
        progress={}
        bst = xgb.train(param, dtrain,num_round,evals=watchlist,early_stopping_rounds=5,evals_result=progress)
        
        plt.plot([i for i in range(num_round)],progress["train"]["mlogloss"],label="train")
        plt.plot([i for i in range(num_round)],progress["test"]["mlogloss"],label="train")
        plt.xlabel('iteration')
        plt.ylabel('logloss')
        plt.show()
        
    return bst

# %% [markdown]
# ### split into train and held out data

# %%
X_train, X_test, y_train, y_test = train_test_split(df[x_col], df['y'], test_size=0.2, random_state=42,stratify=df['y'])

# %%
bst = train_xgb_cv(X_train,y_train)
# Out:
# [    2     4     5 ... 81409 81410 81411]
# C:\Users\Michael Davidoff\.anaconda\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [0]	train-mlogloss:0.987263	test-mlogloss:1.02208
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 5 rounds.
# [1]	train-mlogloss:0.911714	test-mlogloss:0.976852
# [2]	train-mlogloss:0.855429	test-mlogloss:0.948377
# [3]	train-mlogloss:0.811758	test-mlogloss:0.930452
# [4]	train-mlogloss:0.776484	test-mlogloss:0.919448
# [5]	train-mlogloss:0.748132	test-mlogloss:0.912671
# [6]	train-mlogloss:0.723506	test-mlogloss:0.90874
# [7]	train-mlogloss:0.701366	test-mlogloss:0.906204
# [8]	train-mlogloss:0.683096	test-mlogloss:0.905082
# [9]	train-mlogloss:0.664897	test-mlogloss:0.904348
# [    0     1     2 ... 81408 81409 81411]
# [0]	train-mlogloss:0.985138	test-mlogloss:1.02109
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 5 rounds.
# [1]	train-mlogloss:0.908373	test-mlogloss:0.974355
# [2]	train-mlogloss:0.851945	test-mlogloss:0.946291
# [3]	train-mlogloss:0.808389	test-mlogloss:0.928551
# [4]	train-mlogloss:0.774403	test-mlogloss:0.916666
# [5]	train-mlogloss:0.743426	test-mlogloss:0.909459
# [6]	train-mlogloss:0.718128	test-mlogloss:0.905037
# [7]	train-mlogloss:0.698576	test-mlogloss:0.902204
# [8]	train-mlogloss:0.678005	test-mlogloss:0.900792
# [9]	train-mlogloss:0.659846	test-mlogloss:0.899667
# [    0     1     3 ... 81404 81405 81410]
# [0]	train-mlogloss:0.987104	test-mlogloss:1.02098
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 5 rounds.
# [1]	train-mlogloss:0.911161	test-mlogloss:0.975828
# [2]	train-mlogloss:0.856221	test-mlogloss:0.9472
# [3]	train-mlogloss:0.811232	test-mlogloss:0.928854
# [4]	train-mlogloss:0.776481	test-mlogloss:0.917513
# [5]	train-mlogloss:0.74654	test-mlogloss:0.910109
# [6]	train-mlogloss:0.720728	test-mlogloss:0.90571
# [7]	train-mlogloss:0.696798	test-mlogloss:0.902816
# [8]	train-mlogloss:0.678565	test-mlogloss:0.900518
# [9]	train-mlogloss:0.660696	test-mlogloss:0.899884

# %% [markdown]
# ### with these params (high depth) and features, most of the learning is done in a few iterations.
# ### as for model performance, lower depth and eta with more iterations will probably reach a better model. (not to mention param tunning)

# %% [markdown]
# ### define and use a function that plots the feature importance of our ensemble model.

# %%
def importance(model,importance_type='gain',write=False,path=""):
    
    fig = plt.figure(figsize=(10,10))
    ax = fig.gca()
    xgb.plot_importance(model, max_num_features=30, height=0.8, ax=ax,importance_type=importance_type)
    if write:
       plt.savefig('{}/importance.png'.format(path))

# %%
importance_types = ['weight', 'gain', 'cover', 'total_gain', 'total_cover']
for f in importance_types :
    importance(bst,importance_type=f)
    plt.title(f)
    plt.show()

# %% [markdown]
# ### importance plots insghts:
#     1. number_inpatient is the feature that provides the highest gain and is the fifth in terms of cover.
#     2. the second and third most important features are the "other" that replaced low frequency values, therefore they most be checked, maybe there is a specific value inside all of the "others" that drives the gain high.

# %%
shap_values = shap.TreeExplainer(bst).shap_values(X_test[x_col])

# %% [markdown]
# ### shap summary plot for NO readmitted

# %%
shap.summary_plot(shap_values[0], X_test)

# %% [markdown]
# ### NO readmitted shap insights:
#     1. the lower the number_inpatient the higher the chance for being NO readmitted.
#     2. same for number _diagnoses
#     3. when diabetedMed = NO the higher the chance of being readmitted NO
#     3. etc

# %% [markdown]
# ### shap summary plot for >30 readmitted

# %%
shap.summary_plot(shap_values[1], X_test)

# %% [markdown]
# ### above 30 readmitted shap insights:
#     1. the higher the number_inpatient the higher the prediction for being >30 readmitted.
#     2. same for number _diagnoses
#     3. when diabetedMed = NO the lower the prediction of being readmitted >30
#     3. etc

# %% [markdown]
# ### shap summary plot for <30 readmitted

# %%
shap.summary_plot(shap_values[2], X_test)

# %% [markdown]
# ### under 30 readmitted shap insights:
#     1. the higher the number_inpatient the higher the prediction for being <30 readmitted.
#     2. same for number _diagnoses
#     3. when discharge_disposition_id =1 the lower the prediction are of being readmittted <30
#     3. etc

# %% [markdown]
# ### lets look for interactions (on > 30)

# %%
shap.dependence_plot("age_num", shap_values[1], X_test)

# %% [markdown]
# ### age dependence plot insight:
#     1. up to age 50, when discharge disposition id = other (low frequency value, could be a specific value inside should to check that), it pushes the prediction up, while after age 50 it pushes the prediction down.

# %% [markdown]
# ### conclusion:
# it is always fun to investigate fresh data.
#
# more things I would have done:
#
#     pair plot,
#     chi square test,
#     feature scaling,
#     feature engineerinrg,
#     param optimzation,
#     test more interactions and add features based on them,
#     test more algos.
#     deal with missing values.
#     get info of data origin.
#     check if should have used group k fold by patient_id. (maybe some patients with almsot the same feaures have higher rates and the model can learn to identify the patient)
